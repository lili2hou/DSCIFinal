# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)
#
# Make sure to view the video lessons to get the full explanation!

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %% [markdown]
# ## 这章多练习，多创建几个copy, 代码就是打出来的。

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %% [markdown]
# ### Q: 创建一个函数 last_four, 使用apply, 创建新列 last_four

# %%
def last_four(x):
    return str(x)[-4:]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['last_four']=df['CC Number'].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %% [markdown]
# ### Using .apply() with more complex functions

# %% [markdown]
# ### Q: 创建新的列 Expensive 超过十快 ¥¥¥, 小于10块 ¥,在中间 ¥¥

# %%
def price(x):
    if x < 10:
        return '$'
    elif 10<=x<20:
        return '$$'
    else:
        return '$$$'

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %%
df['Expensive']=df['price_per_person'].apply(price)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive
# 0  Christy Cunningham  3560325168603410    Sun2959      3410         $
# 1      Douglas Tucker  4478071379779230    Sun4608      9230         $
# 2      Travis Walters  6011812112971322    Sun4458      1322         $
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221         $

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def simple(num):
    return num*2

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"

# %% [markdown]
# ## 这块容易犯浑 ： .apply( lamda x: quality(x),axis=1) , 注意axis=1的位置

# %%
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#   Tip Quality
# 0       Other
# 1       Other
# 2       Other
# 3       Other
# 4       Other

# %% [markdown]
# ### Q: 用vectorize 计算Tip quality - tip/total_bill

# %%
def quality(tip,total_bill):
    if tip/total_bill <0.25:
        return 'poor'
    else:
        return 'Normal'

# %%
import numpy as np
import pandas as pd

# %%
df['Tip Quality']=np.vectorize(quality)(df['tip'],df['total_bill'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410         $
# 1      Douglas Tucker  4478071379779230    Sun4608      9230         $
# 2      Travis Walters  6011812112971322    Sun4458      1322         $
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221         $
#
#   Tip Quality
# 0        poor
# 1        poor
# 2        poor
# 3        poor
# 4        poor

# %% [markdown]
# So, which one is faster?

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 5.0198852999999986

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.21840849999999534

# %% [markdown]
# Wow! Vectorization is much faster! Keep **np.vectorize()** in mind for the future.
#
# Full Details:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 0    Christy Cunningham  3560325168603410    Sun2959      3410         $
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508         $
# 59          Brian Ortiz  6596453823950595    Sat8139      0595        $$
# 23       Lance Peterson  3542584061609808     Sat239      9808         $
# 212     Alex Williamson      676218815212    Sat4590      5212        $$
# 170       Gregory Clark  5473850968388236    Sat1954      8236        $$
#
#     Tip Quality
# 67       Normal
# 236        poor
# 92         poor
# 111        poor
# 0          poor
# ..          ...
# 141        poor
# 59         poor
# 23         poor
# 212        poor
# 170        poor
#
# [244 rows x 14 columns]

# %%
# Helpful if you want to reorder after a sort
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID last_four Expensive  \
# 67        Tiffany Brock  4359488526995267    Sat3455      5267         $
# 111         Terri Jones  3559221007826887    Sat4801      6887         $
# 92         Leah Ramirez  3508911676966392    Fri3780      6392         $
# 236       Matthew Myers  3543676378973965    Sat5032      3965         $
# 0    Christy Cunningham  3560325168603410    Sun2959      3410         $
# ..                  ...               ...        ...       ...       ...
# 141      Steven Carlson  3526515703718508   Thur1025      8508         $
# 59          Brian Ortiz  6596453823950595    Sat8139      0595        $$
# 23       Lance Peterson  3542584061609808     Sat239      9808         $
# 212     Alex Williamson      676218815212    Sat4590      5212        $$
# 170       Gregory Clark  5473850968388236    Sat1954      8236        $$
#
#     Tip Quality
# 67       Normal
# 111        poor
# 92         poor
# 236        poor
# 0          poor
# ..          ...
# 141        poor
# 59         poor
# 23         poor
# 212        poor
# 170        poor
#
# [244 rows x 14 columns]

# %% [markdown]
# ## reorder columns

# %%
df.columns.tolist()
# Out:
# ['total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'price_per_person',
#  'Payer Name',
#  'CC Number',
#  'Payment ID',
#  'last_four',
#  'Expensive',
#  'Tip Quality']

# %%
df=df[[
 'tip','total_bill',
 'sex',
 'smoker',
 'day',
 'time',
 'size',
 'price_per_person',
 'Payer Name',
 'CC Number',
 'Payment ID',
 'last_four',
 'Expensive',
 'Tip Quality']]

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410         $
# 1      Douglas Tucker  4478071379779230    Sun4608      9230         $
# 2      Travis Walters  6011812112971322    Sun4458      1322         $
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221         $
#
#   Tip Quality
# 0        poor
# 1        poor
# 2        poor
# 3        poor
# 4        poor

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.corr()
# Out:
#                        tip  total_bill      size  price_per_person  CC Number
# tip               1.000000    0.675734  0.489299          0.347405   0.110857
# total_bill        0.675734    1.000000  0.598315          0.647554   0.104576
# size              0.489299    0.598315  1.000000         -0.175359  -0.030239
# price_per_person  0.347405    0.647554 -0.175359          1.000000   0.135240
# CC Number         0.110857    0.104576 -0.030239          0.135240   1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %%
df.head()
# Out:
#              tip  total_bill     sex smoker  day    time  size  \
# Payment ID
# Sun2959     1.01       16.99  Female     No  Sun  Dinner     2
# Sun4608     1.66       10.34    Male     No  Sun  Dinner     3
# Sun4458     3.50       21.01    Male     No  Sun  Dinner     3
# Sun5260     3.31       23.68    Male     No  Sun  Dinner     2
# Sun2251     3.61       24.59  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number last_four  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      3410
# Sun4608                 3.45      Douglas Tucker  4478071379779230      9230
# Sun4458                 7.00      Travis Walters  6011812112971322      1322
# Sun5260                11.84    Nathaniel Harris  4676137647685994      5994
# Sun2251                 6.15        Tonya Carter  4832732618637221      7221
#
#            Expensive Tip Quality
# Payment ID
# Sun2959            $        poor
# Sun4608            $        poor
# Sun4458            $        poor
# Sun5260           $$        poor
# Sun2251            $        poor

# %%
df['tip'].max()
# Out:
# 10.0

# %%
df['tip'].idxmax()

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 'Sat1954'

# %%
df['total_bill'].idxmin()
# Out:
# 'Sat3455'

# %%
df.iloc[0]
# Out:
# tip                               1.01
# total_bill                       16.99
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# last_four                         3410
# Expensive                            $
# Tip Quality                       poor
# Name: Sun2959, dtype: object

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                               10
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# last_four                       8236
# Expensive                        $$$
# Tip Quality                    Other
# Name: 170, dtype: object

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.head()
# Out:
#              tip  total_bill     sex smoker  day    time  size  \
# Payment ID
# Sun2959     1.01       16.99  Female     No  Sun  Dinner     2
# Sun4608     1.66       10.34    Male     No  Sun  Dinner     3
# Sun4458     3.50       21.01    Male     No  Sun  Dinner     3
# Sun5260     3.31       23.68    Male     No  Sun  Dinner     2
# Sun2251     3.61       24.59  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number last_four  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      3410
# Sun4608                 3.45      Douglas Tucker  4478071379779230      9230
# Sun4458                 7.00      Travis Walters  6011812112971322      1322
# Sun5260                11.84    Nathaniel Harris  4676137647685994      5994
# Sun2251                 6.15        Tonya Carter  4832732618637221      7221
#
#            Expensive Tip Quality
# Payment ID
# Sun2959            $        poor
# Sun4608            $        poor
# Sun4458            $        poor
# Sun5260           $$        poor
# Sun2251            $        poor

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()
# Out:
#              tip  total_bill     sex smoker  day    time  size  \
# Payment ID
# Sun2959     1.01       16.99  Female     No  Sun  Dinner     2
# Sun4608     1.66       10.34    Male     No  Sun  Dinner     3
# Sun4458     3.50       21.01    Male     No  Sun  Dinner     3
# Sun5260     3.31       23.68    Male     No  Sun  Dinner     2
# Sun2251     3.61       24.59  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number last_four  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      3410
# Sun4608                 3.45      Douglas Tucker  4478071379779230      9230
# Sun4458                 7.00      Travis Walters  6011812112971322      1322
# Sun5260                11.84    Nathaniel Harris  4676137647685994      5994
# Sun2251                 6.15        Tonya Carter  4832732618637221      7221
#
#            Expensive Tip Quality
# Payment ID
# Sun2959            $        poor
# Sun4608            $        poor
# Sun4458            $        poor
# Sun5260           $$        poor
# Sun2251            $        poor

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')
# Out:
# Payment ID
# Sun2959    poor
# Sun4608    poor
# Sun4458    poor
# Sun5260    poor
# Sun2251    poor
#            ...
# Sat2657    poor
# Sat1766    poor
# Sat3880    poor
# Sat17      poor
# Thur672    poor
# Name: Tip Quality, Length: 244, dtype: object

# %%
df['Tip Quality'] = df['Tip Quality'].replace(to_replace='poor',value='Ok')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['Tip Quality']=df['Tip Quality'].replace(to_replace='Ok',value='lili')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/new_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tip Quality'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/95/mbtd2rs958q4r3x_v30jqjv80000gn/T/ipykernel_77416/3682668715.py in <module>
# ----> 1 df['Tip Quality']=df['Tip Quality'].replace(to_replace='Ok',value='lili')
#       2 df.head()
#
# ~/opt/anaconda3/envs/new_env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/new_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 'Tip Quality'

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time']=df['time'].map(my_map)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun    D     2              8.49
# 1       10.34  1.66    Male     No  Sun    D     3              3.45
# 2       21.01  3.50    Male     No  Sun    D     3              7.00
# 3       23.68  3.31    Male     No  Sun    D     2             11.84
# 4       24.59  3.61  Female     No  Sun    D     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['time'] = df['time'].replace(['D','L'],['Dinner','Lunch'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
mymap={'Dinner':'Di','Lunch':'Lu'}
df['time']=df['time'].map(mymap)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun   Di     2              8.49
# 1       10.34  1.66    Male     No  Sun   Di     3              3.45
# 2       21.01  3.50    Male     No  Sun   Di     3              7.00
# 3       23.68  3.31    Male     No  Sun   Di     2             11.84
# 4       24.59  3.61  Female     No  Sun   Di     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
new_df=pd.DataFrame([1,2,2],['a','b','c'],['x'])
new_df
# Out:
#    x
# a  1
# b  2
# c  2

# %%
new_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
new_df=new_df.drop_duplicates()
new_df
# Out:
#    x
# a  1
# b  2

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary
# right: A scalar value that defines the right boundary
# inclusive: A Boolean value which is True by default. If False, it excludes the two passed arguments while checking.

# %%
df['total_bill'].between(10,20,inclusive=True).head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: total_bill, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)].head()
# Out:
#     total_bill   tip     sex smoker  day time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun   Di     2              8.49
# 1        10.34  1.66    Male     No  Sun   Di     3              3.45
# 8        15.04  1.96    Male     No  Sun   Di     2              7.52
# 9        14.78  3.23    Male     No  Sun   Di     2              7.39
# 10       10.27  1.71    Male     No  Sun   Di     2              5.14
#
#             Payer Name         CC Number Payment ID
# 0   Christy Cunningham  3560325168603410    Sun2959
# 1       Douglas Tucker  4478071379779230    Sun4608
# 8      Joseph Mcdonald  3522866365840377    Sun6820
# 9        Jerome Abbott  3532124519049786    Sun3775
# 10       William Riley      566287581219    Sun2546

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day time  size  price_per_person  \
# 209       12.76  2.23  Female    Yes   Sat   Di     2              6.38
# 205       16.47  3.23  Female    Yes  Thur   Lu     3              5.49
# 228       13.28  2.72    Male     No   Sat   Di     2              6.64
# 180       34.65  3.68    Male    Yes   Sun   Di     4              8.66
# 101       15.38  3.00  Female    Yes   Fri   Di     2              7.69
#
#            Payer Name         CC Number Payment ID
# 209  Sarah Cunningham   341876516331163    Sat1274
# 205       Carly Reyes     4787787236486   Thur8084
# 228       Glenn Jones      502061651712    Sat2937
# 180  James Hebert DDS      676168737648    Sun7544
# 101     Tiffany Colon  6011012799432041    Fri8382

# %%
new=df.sample(frac=0.1)
new.count()
df.count()
# Out:
# total_bill          244
# tip                 244
# sex                 244
# smoker              244
# day                 244
# time                244
# size                244
# price_per_person    244
# Payer Name          244
# CC Number           244
# Payment ID          244
# dtype: int64

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %%
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat   Di     3             16.94
# 212       48.33   9.00    Male     No   Sat   Di     4             12.08
# 23        39.42   7.58    Male     No   Sat   Di     4              9.86
# 59        48.27   6.73    Male     No   Sat   Di     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lu     6              5.72
# 183       23.17   6.50    Male    Yes   Sun   Di     4              5.79
# 214       28.17   6.50  Female    Yes   Sat   Di     3              9.39
# 47        32.40   6.00    Male     No   Sun   Di     4              8.10
# 239       29.03   5.92    Male     No   Sat   Di     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lu     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# 212    Alex Williamson      676218815212    Sat4590
# 23      Lance Peterson  3542584061609808     Sat239
# 59         Brian Ortiz  6596453823950595    Sat8139
# 141     Steven Carlson  3526515703718508   Thur1025
# 183  Dr. Michael James     4718501859162    Sun6059
# 214    Marissa Jackson  4922302538691962    Sat3374
# 47        James Barnes  3552002592874186    Sun9677
# 239      Michael Avila  5296068606052842    Sat2657
# 88        Roger Taylor     4410248629955   Thur9003

# %% [markdown]
# df.nsmallest(10,'tips')

# %%
df.nsmallest(10,'tip')
# Out:
#      total_bill   tip     sex smoker   day time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat   Di     1              3.07
# 92         5.75  1.00  Female    Yes   Fri   Di     2              2.88
# 111        7.25  1.00  Female     No   Sat   Di     1              7.25
# 236       12.60  1.00    Male    Yes   Sat   Di     2              6.30
# 0         16.99  1.01  Female     No   Sun   Di     2              8.49
# 215       12.90  1.10  Female    Yes   Sat   Di     2              6.45
# 237       32.83  1.17    Male    Yes   Sat   Di     2             16.42
# 75        10.51  1.25    Male     No   Sat   Di     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lu     2              4.26
# 235       10.07  1.25    Male     No   Sat   Di     2              5.04
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959
# 215        Jessica Owen     4726904879471    Sat6983
# 237        Thomas Brown  4284722681265508    Sat2929
# 75        Kenneth Hayes   213142079731108    Sat5056
# 135      Rebecca Harris  4320272020376174   Thur6600
# 235       Sean Gonzalez  3534021246117605    Sat4615
