# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)
#
# Make sure to view the video lessons to get the full explanation!

# %% [markdown]
# ### 这节开始就有点难了，要用心 多花时间 砸时间下去！

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ### Q： def一个函数，使用apply 输出cc number列的后四位数字。

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df['CC Number'][0]
# Out:
# 3560325168603410

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %% [markdown]
# ### Using .apply() with more complex functions

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['Expensive'] = df['total_bill'].apply(yelp)

# %%
# df

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def simple(num):
    return num*2

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return 'normal'
    else:
        return 'strange'

# %%
df['yelp']=df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#       yelp
# 0  strange
# 1  strange
# 2  strange
# 3  strange
# 4  strange

# %%
def quality(total_bill,tip):
    if total_bill/tip > 0.25:
        return 'Normal'
    else:
        return'other'

# %%
quality(20,10)
# Out:
# 'Normal'

# %%
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df:quality(df['total_bill'],df['tip']),axis=1)
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
# 5          Erik Smith   213140353657882    Sun9679      7882        $$
# 6  Kristopher Johnson  2223727524230344    Sun5985      0344         $
# 7         Robert Buck  3514785077705092    Sun8157      5092        $$
# 8     Joseph Mcdonald  3522866365840377    Sun6820      0377        $$
# 9       Jerome Abbott  3532124519049786    Sun3775      9786        $$
#
#       yelp Tip Quality
# 0  strange      Normal
# 1  strange      Normal
# 2  strange      Normal
# 3  strange      Normal
# 4  strange      Normal
# 5  strange      Normal
# 6  strange      Normal
# 7  strange      Normal
# 8  strange      Normal
# 9  strange      Normal

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#       yelp Tip Quality
# 0  strange      Normal
# 1  strange      Normal
# 2  strange      Normal
# 3  strange      Normal
# 4  strange      Normal

# %%
import numpy as np

# %%
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df['YELP']=np.vectorize(quality)(df['total_bill'],df['tip'])
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#       yelp Tip Quality    YELP
# 0  strange      Normal  Normal
# 1  strange      Normal  Normal
# 2  strange      Normal  Normal
# 3  strange      Normal  Normal
# 4  strange      Normal  Normal

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
#
#       yelp Tip Quality    YELP
# 0  strange      Normal  Normal
# 1  strange      Normal  Normal
# 2  strange      Normal  Normal
# 3  strange      Normal  Normal
# 4  strange      Normal  Normal

# %%
df['Tip Quality']=np.vectorize(quality)(df['total_bill'],df['tip'])
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID last_four Expensive  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410        $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230        $$
# 2      Travis Walters  6011812112971322    Sun4458      1322        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994        $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221        $$
# 5          Erik Smith   213140353657882    Sun9679      7882        $$
# 6  Kristopher Johnson  2223727524230344    Sun5985      0344         $
# 7         Robert Buck  3514785077705092    Sun8157      5092        $$
# 8     Joseph Mcdonald  3522866365840377    Sun6820      0377        $$
# 9       Jerome Abbott  3532124519049786    Sun3775      9786        $$
#
#       yelp Tip Quality    YELP
# 0  strange      Normal  Normal
# 1  strange      Normal  Normal
# 2  strange      Normal  Normal
# 3  strange      Normal  Normal
# 4  strange      Normal  Normal
# 5  strange      Normal  Normal
# 6  strange      Normal  Normal
# 7  strange      Normal  Normal
# 8  strange      Normal  Normal
# 9  strange      Normal  Normal

# %%
expre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/95/mbtd2rs958q4r3x_v30jqjv80000gn/T/ipykernel_50468/2037278405.py in <module>
# ----> 1 expre
#
# NameError: name 'expre' is not defined

# %% [markdown]
# So, which one is faster?

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 3.027733041999454

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.30384679199778475

# %% [markdown]
# Wow! Vectorization is much faster! Keep **np.vectorize()** in mind for the future.
#
# Full Details:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# # ！新的章节

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %% [markdown]
# ### Q1: 对tips,size进行sort

# %%
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 111         Terri Jones  3559221007826887    Sat4801
# 92         Leah Ramirez  3508911676966392    Fri3780
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959
# ..                  ...               ...        ...
# 141      Steven Carlson  3526515703718508   Thur1025
# 59          Brian Ortiz  6596453823950595    Sat8139
# 23       Lance Peterson  3542584061609808     Sat239
# 212     Alex Williamson      676218815212    Sat4590
# 170       Gregory Clark  5473850968388236    Sat1954
#
# [244 rows x 11 columns]

# %% [markdown]
# ### Q2: 把tip 这列调到前面来，调换列到顺序

# %%
df.columns.tolist()
# Out:
# ['total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'price_per_person',
#  'Payer Name',
#  'CC Number',
#  'Payment ID']

# %%
df=df[['total_bill',
 'tip',
 'sex',
 'smoker',
 'day',
 'time',
 'size',
 'price_per_person',
 'Payer Name',
 'CC Number',
 'Payment ID']]

# %%
df.columns.tolist()
# Out:
# ['total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'price_per_person',
#  'Payer Name',
#  'CC Number',
#  'Payment ID']

# %%
df=df[['tip','total_bill',
 'sex',
 'smoker',
 'day',
 'time',
 'size',
 'price_per_person',
 'Payer Name',
 'CC Number',
 'Payment ID']]

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ### A2: 先把列名用df.columns.tolist() 变成list，再把list更改

# %% [markdown]
# <a id='corr'></a>
# ## 看相关性
# ### df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.corr()
# Out:
#                        tip  total_bill      size  price_per_person  CC Number
# tip               1.000000    0.675734  0.489299          0.347405   0.110857
# total_bill        0.675734    1.000000  0.598315          0.647554   0.104576
# size              0.489299    0.598315  1.000000         -0.175359  -0.030239
# price_per_person  0.347405    0.647554 -0.175359          1.000000   0.135240
# CC Number         0.110857    0.104576 -0.030239          0.135240   1.000000

# %% [markdown]
# ### 看指定两列的相关性

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %% [markdown]
# ### Q3: 找到total bill最大值的index, 并取去这一行的所有值

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[170]
# Out:
# tip                               10
# total_bill                     50.81
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df['total_bill'].max()
# Out:
# 50.81

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
# ### 计算各个种类又多少，like 男人和女人各有多少
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def quality(tip,total_bill):
    if tip/total_bill > 0.25:
        return 'Normal'
    else :
        return 'Poor'

# %% [markdown]
# ### 回顾使用函数 np.vectorize()

# %% [markdown]
# ## Q3: 构建一个函数quality，并创建一个新的Tip Quality 列，并替换列的内容

# %%
import numpy as np
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df['Tip Quality']= np.vectorize(quality)(df['tip'],df['total_bill'])
df
# Out:
#       tip  total_bill     sex smoker   day    time  size  price_per_person  \
# 0    1.01       16.99  Female     No   Sun  Dinner     2              8.49
# 1    1.66       10.34    Male     No   Sun  Dinner     3              3.45
# 2    3.50       21.01    Male     No   Sun  Dinner     3              7.00
# 3    3.31       23.68    Male     No   Sun  Dinner     2             11.84
# 4    3.61       24.59  Female     No   Sun  Dinner     4              6.15
# ..    ...         ...     ...    ...   ...     ...   ...               ...
# 239  5.92       29.03    Male     No   Sat  Dinner     3              9.68
# 240  2.00       27.18  Female    Yes   Sat  Dinner     2             13.59
# 241  2.00       22.67    Male    Yes   Sat  Dinner     2             11.34
# 242  1.75       17.82    Male     No   Sat  Dinner     2              8.91
# 243  3.00       18.78  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Tip Quality
# 0    Christy Cunningham  3560325168603410    Sun2959        Poor
# 1        Douglas Tucker  4478071379779230    Sun4608        Poor
# 2        Travis Walters  6011812112971322    Sun4458        Poor
# 3      Nathaniel Harris  4676137647685994    Sun5260        Poor
# 4          Tonya Carter  4832732618637221    Sun2251        Poor
# ..                  ...               ...        ...         ...
# 239       Michael Avila  5296068606052842    Sat2657        Poor
# 240      Monica Sanders  3506806155565404    Sat1766        Poor
# 241          Keith Wong  6011891618747196    Sat3880        Poor
# 242        Dennis Dixon     4375220550950      Sat17        Poor
# 243     Michelle Hardin  3511451626698139    Thur672        Poor
#
# [244 rows x 12 columns]

# %% [markdown]
# ## A3: 直接使用replace函数

# %%
df['Tip Quality']=df['Tip Quality'].replace(to_replace='Poor',value='Ugly')

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959        Ugly
# 1      Douglas Tucker  4478071379779230    Sun4608        Ugly
# 2      Travis Walters  6011812112971322    Sun4458        Ugly
# 3    Nathaniel Harris  4676137647685994    Sun5260        Ugly
# 4        Tonya Carter  4832732618637221    Sun2251        Ugly

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality
# 0  Christy Cunningham  3560325168603410    Sun2959        Ugly
# 1      Douglas Tucker  4478071379779230    Sun4608        Ugly
# 2      Travis Walters  6011812112971322    Sun4458        Ugly
# 3    Nathaniel Harris  4676137647685994    Sun5260        Ugly
# 4        Tonya Carter  4832732618637221    Sun2251        Ugly

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['time'].unique()
# Out:
# array([nan], dtype=object)

# %% [markdown]
# <a id='map'></a>
# ### map

# %% [markdown]
# ### Q4: 使用map, 将Tip Quality 里的‘Ugly' -> 'U', 'Normal' -> 'N'

# %%
my_map = {'Dinner':'D','Lunch':'L','NaN':'N'}

# %%
df['time'].map(my_map)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 239    NaN
# 240    NaN
# 241    NaN
# 242    NaN
# 243    NaN
# Name: time, Length: 244, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  NaN     2              8.49
# 1       10.34  1.66    Male     No  Sun  NaN     3              3.45
# 2       21.01  3.50    Male     No  Sun  NaN     3              7.00
# 3       23.68  3.31    Male     No  Sun  NaN     2             11.84
# 4       24.59  3.61  Female     No  Sun  NaN     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 214    False
# 215    False
# 216    False
# 217    False
# 218    False
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary
# right: A scalar value that defines the right boundary
# inclusive: A Boolean value which is True by default. If False, it excludes the two passed arguments while checking.

# %% [markdown]
# ### Q4: 输出total_bill 在10-20之间的行

# %%
df.head()
# Out:
#     tip  total_bill     sex smoker  day    time  size  price_per_person  \
# 0  1.01       16.99  Female     No  Sun  Dinner     2              8.49
# 1  1.66       10.34    Male     No  Sun  Dinner     3              3.45
# 2  3.50       21.01    Male     No  Sun  Dinner     3              7.00
# 3  3.31       23.68    Male     No  Sun  Dinner     2             11.84
# 4  3.61       24.59  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill'].between(10,20,inclusive=True).head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: total_bill, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)]
# Out:
#       tip  total_bill     sex smoker   day    time  size  price_per_person  \
# 0    1.01       16.99  Female     No   Sun  Dinner     2              8.49
# 1    1.66       10.34    Male     No   Sun  Dinner     3              3.45
# 8    1.96       15.04    Male     No   Sun  Dinner     2              7.52
# 9    3.23       14.78    Male     No   Sun  Dinner     2              7.39
# 10   1.71       10.27    Male     No   Sun  Dinner     2              5.14
# ..    ...         ...     ...    ...   ...     ...   ...               ...
# 234  3.00       15.53    Male    Yes   Sat  Dinner     2              7.76
# 235  1.25       10.07    Male     No   Sat  Dinner     2              5.04
# 236  1.00       12.60    Male    Yes   Sat  Dinner     2              6.30
# 242  1.75       17.82    Male     No   Sat  Dinner     2              8.91
# 243  3.00       18.78  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 8       Joseph Mcdonald  3522866365840377    Sun6820
# 9         Jerome Abbott  3532124519049786    Sun3775
# 10        William Riley      566287581219    Sun2546
# ..                  ...               ...        ...
# 234       Tracy Douglas  4097938155941930    Sat7220
# 235       Sean Gonzalez  3534021246117605    Sat4615
# 236       Matthew Myers  3543676378973965    Sat5032
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [130 rows x 11 columns]

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5              5.63
# 136       10.33  2.00  Female     No  Thur   Lunch     2              5.16
# 13        18.43  3.00    Male     No   Sun  Dinner     4              4.61
# 146       18.64  1.36  Female     No  Thur   Lunch     3              6.21
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4              9.50
#
#                 Payer Name         CC Number Payment ID last_four Expensive  \
# 216      Shawn Barnett PhD     4590982568244    Sat7320      8244        $$
# 136            Donna Kelly   180048553626376   Thur1393      6376        $$
# 13            Joshua Jones  6011163105616890    Sun2971      6890        $$
# 146          Kelly Estrada       60463302327   Thur3941      2327        $$
# 56   James Christensen DDS   349793629453226    Sat8903      3226       $$$
#
#     Tip Quality
# 216          Ok
# 136          Ok
# 13           Ok
# 146          Ok
# 56           Ok

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 141       34.30  6.70    Male     No  Thur   Lunch     6              5.72
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2              7.50
# 108       18.24  3.76    Male     No   Sat  Dinner     2              9.12
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 41        17.46  2.54    Male     No   Sun  Dinner     2              8.73
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2              6.90
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 5         25.29  4.71    Male     No   Sun  Dinner     4              6.32
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2              6.08
# 119       24.08  2.92  Female     No  Thur   Lunch     4              6.02
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2             13.64
# 159       16.49  2.00    Male     No   Sun  Dinner     4              4.12
# 26        13.37  2.00    Male     No   Sat  Dinner     2              6.68
# 129       22.82  2.18    Male     No  Thur   Lunch     3              7.61
# 21        20.29  2.75  Female     No   Sat  Dinner     2             10.14
# 94        22.75  3.25  Female     No   Fri  Dinner     2             11.38
# 39        31.27  5.00    Male     No   Sat  Dinner     3             10.42
#
#             Payer Name         CC Number Payment ID last_four Expensive  \
# 73        Julie Holmes  5418689346409571    Sat6065      9571        $$
# 141     Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 239      Michael Avila  5296068606052842    Sat2657      2842        $$
# 237       Thomas Brown  4284722681265508    Sat2929      5508       $$$
# 69           Adam Hall  4700924377057571     Sat855      7571        $$
# 108       Steven Grant  4112810433473856    Sat6376      3856        $$
# 85         Shawna Cook  6011787464177340   Thur7972      7340       $$$
# 156      Ryan Gonzales  3523151482063321    Sun7518      3321       $$$
# 196        Eric Martin    30442491190342   Thur9862      0342        $$
# 41         David Boyer  3536678244278149    Sun9460      8149        $$
# 236      Matthew Myers  3543676378973965    Sat5032      3965        $$
# 225     Whitney Arnold  3579111947217428    Fri6665      7428        $$
# 61      Ryan Hernandez     4766834726806    Sat3030      6806        $$
# 203        Toni Brooks  3582289985920239   Thur7770      0239        $$
# 5           Erik Smith   213140353657882    Sun9679      7882        $$
# 220      Ricky Johnson   213109508670736    Fri4607      0736        $$
# 119     Melanie Jordan      676212062720   Thur8063      2720        $$
# 96         Eric Carter  4563054452787961    Fri3159      7961        $$
# 159   Christopher Soto    30501814271434    Sun1781      1434        $$
# 26          Kyle Avery  6531339539615499    Sat6651      5499        $$
# 129     Raymond Torres     4855776744024   Thur9424      4024        $$
# 21     Natalie Gardner  5448125351489749    Sat9618      9749        $$
# 94         Jamie Garza      676318332068    Fri2318      2068        $$
# 39   Mr. Brandon Berry  6011525851069856    Sat6373      9856       $$$
#
#     Tip Quality
# 73           Ok
# 141          Ok
# 239          Ok
# 237          Ok
# 69           Ok
# 108          Ok
# 85           Ok
# 156          Ok
# 196          Ok
# 41           Ok
# 236          Ok
# 225          Ok
# 61           Ok
# 203          Ok
# 5            Ok
# 220          Ok
# 119          Ok
# 96           Ok
# 159          Ok
# 26           Ok
# 129          Ok
# 21           Ok
# 94           Ok
# 39           Ok

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %% [markdown]
# ### Q5: 输出前5个最大的tip rows

# %%
df.nlargest(2,'tip',keep='all')
# Out:
#       tip  total_bill   sex smoker  day    time  size  price_per_person  \
# 170  10.0       50.81  Male    Yes  Sat  Dinner     3             16.94
# 212   9.0       48.33  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID Tip Quality
# 170    Gregory Clark  5473850968388236    Sat1954        Ugly
# 212  Alex Williamson      676218815212    Sat4590        Ugly

# %%
df.nlargest(10,'tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID last_four Expensive  \
# 170      Gregory Clark  5473850968388236    Sat1954      8236       $$$
# 212    Alex Williamson      676218815212    Sat4590      5212       $$$
# 23      Lance Peterson  3542584061609808     Sat239      9808       $$$
# 59         Brian Ortiz  6596453823950595    Sat8139      0595       $$$
# 141     Steven Carlson  3526515703718508   Thur1025      8508       $$$
# 183  Dr. Michael James     4718501859162    Sun6059      9162        $$
# 214    Marissa Jackson  4922302538691962    Sat3374      1962        $$
# 47        James Barnes  3552002592874186    Sun9677      4186       $$$
# 239      Michael Avila  5296068606052842    Sat2657      2842        $$
# 88        Roger Taylor     4410248629955   Thur9003      9955        $$
#
#     Tip Quality
# 170          Ok
# 212          Ok
# 23           Ok
# 59           Ok
# 141          Ok
# 183    Generous
# 214          Ok
# 47           Ok
# 239          Ok
# 88           Ok

# %% [markdown]
# ----
